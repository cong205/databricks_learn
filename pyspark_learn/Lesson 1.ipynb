# %% [markdown]
# #Reading From CSV File

# %%
df = (
    spark.read.option("header","True")
    .option("inferSchema", "True")
    .csv("/Volumes/workspace/bronze/source_systems/source_crm/cust_info.csv")
)

# %% [markdown]
# # Các thao tác trên dataframe

# %% [markdown]
# ## Kiểu của dataframe

# %%
type(df)

# %% [markdown]
# ## kiểu của các cột trong dataframe

# %%
df.printSchema()

# %% [markdown]
# ## đọc các hàng ở đầu

# %%
df.head(3)

# %% [markdown]
# ## chọn cột

# %%
df.select("cst_firstname")

# %%
df.select("cst_firstname").show()

# %%
df.select(["cst_firstname","cst_lastname"]).show()

# %% [markdown]
# ## mô tả dataframe (describe)

# %%
df.describe().show()

# %% [markdown]
# ## adding columns in data frame

# %%
from pyspark.sql.functions import concat_ws
df=df.withColumn("cst_fullname", concat_ws(" ", df["cst_firstname"], df["cst_lastname"]))

# %%
df.show()

# %% [markdown]
# ## drop the columns

# %%
df=df.drop('cst_fullname')

# %%
df.show()

# %% [markdown]
# ## rename the columns

# %%
df.withColumnRenamed('tên cũ','tên mới').show()
